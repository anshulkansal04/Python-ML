# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('whdata.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      50     122
# 2      53     125
# 3      56     130
# 4      59     132

# %%
## Scatter Plot
plt.scatter(df['Weight'],df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
## Correlation
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.997149
# Height  0.997149  1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
X = df[['Weight']] # Must be in Dataframe or 2d Array, must not be in series
Y = df['Height'] # Can be in Datatframe ot Series
# Out:
#    Weight
# 0      45
# 1      50
# 2      53
# 3      56
# 4      59

# %%
X_series = df['Weight']
